# %%
# Data Manipulation
import pandas as pd
import numpy as np
import json
from pathlib import Path
from pandas import DataFrame

# Natural Language Processing
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize
from pandas.io.json import json_normalize

import pickle

# %%
from gensim.models.doc2vec import Doc2Vec

model= Doc2Vec.load("d2v10.model")

# %%
result = pd.read_csv("Apple Stock-labelled.csv", encoding = "ISO-8859-1")

# %%
result.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1           332
# 2           2           664
# 3           3           996
# 4           4          1328
#
#                                                  url  \
# 0  https://finance.yahoo.com/news/greenpeace-call...
# 1  https://finance.yahoo.com/news/us-indexes-rega...
# 2  https://finance.yahoo.com/m/fc555228-3303-3d22...
# 3  https://finance.yahoo.com/m/18ac2ae1-6321-33af...
# 4  https://finance.yahoo.com/m/a85e46cc-c988-320f...
#
#                                                title        date  \
# 0  Greenpeace Calls Out Alibaba, Tencent in Maide...  2020-01-09
# 1  US Indexes Regain Some Losses to Close Higher ...  2020-01-07
# 2  Stock Market Roars Back After Trump Iran Speec...  2020-01-07
# 3  AppleÃÂ¢ÃÂÃÂs stock has now doubled in a ...  2020-01-07
# 4  Trump in uncharted territory ÃÂ¢ÃÂÃÂ here...  2020-01-07
#
#                                              summary   close    high     low  \
# 0  (Bloomberg) -- Greenpeace, calling attention t...  309.63  310.43  306.20
# 1              S&P; 500 up 0.49% Continue reading...  298.39  300.90  297.48
# 2  The stock market rallied Wednesday after a lat...  298.39  300.90  297.48
# 3  Shares of Apple Inc. surged to another record ...  298.39  300.90  297.48
# 4  President Trump acted where his two immediate ...  298.39  300.90  297.48
#
#       open  difference label
# 0  307.235       8.360   buy
# 1  299.840      -0.462  hold
# 2  299.840      -0.462  hold
# 3  299.840      -0.462  hold
# 4  299.840      -0.462  hold

# %%
#apply Word2Vec on clean_headline
# One way of doing this is creating a new dataframe that will contain the word vectors.
test_empty_df = pd.DataFrame()

# Interate over pandas dataframe and for each string of text, save the summed vector to test_empty_df
for index, row in result.iterrows():
    #print(type(row['body']))
    sentence = model.infer_vector(row['title'].split())
    # reshape it so it will be added as a row, not a column
    sentence_reshaped = np.reshape(sentence, (1, 10))
    # add the vector to the dataframe
    test_empty_df = test_empty_df.append(pd.DataFrame(sentence_reshaped))

test_empty_df = test_empty_df.reset_index(drop = True)

final_df = pd.concat([test_empty_df,result[['label']]],axis=1)
final_df.to_csv('Doc2Vec Titles - 10 - Original.csv')
